# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from google.colab import drive

# %%
drive.mount('/content/drive')
data = pd.read_excel('/content/drive/MyDrive/Maestria/Datos/base-de-datos-violencia-intrafamiliar-ano-2024_v3.xlsx')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.head()
# Out:
#    HEC_DIA  HEC_MES  HEC_ANO  HEC_DEPTO  HEC_DEPTOMCPIO  HEC_TIPAGRE  \
# 0        4       11     2024          1             110         1122
# 1       24        3     2024          2             202         1222
# 2       99       99     9999          1             101         1122
# 3       28        3     2024          2             202         1122
# 4       12        7     2024          7             706         2122
#
#    NUMERO_BOLETA  DIA_EMISION  MES_EMISION  ANO_EMISION  ...  ARTICULOCODPEN2  \
# 0            367            4           11         2024  ...              NaN
# 1              5           25            3         2024  ...              NaN
# 2            430            2            3         2024  ...              NaN
# 3              6           28            3         2024  ...              NaN
# 4             16           24            7         2024  ...              NaN
#
#    ARTICULOCODPEN3  ARTICULOCODPEN4  ARTICULOTRAS1  ARTICULOTRAS2  \
# ...

# %%
data['depto_guatemala'] = data['HEC_DEPTO'].apply(lambda x: 1 if x == 1 else 0)

# %%
x = data[['AGR_SEXO','AGR_EST_CIV','AGR_TRABAJA', 'AGR_ESCOLARIDAD','AGR_EDAD','AGR_ALFAB']]
x = x.fillna(0)
y = data['depto_guatemala']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = Sequential()
model.add(Dense(8, input_dim=6, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=75, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/75
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7805 - loss: 0.4740 - val_accuracy: 0.7790 - val_loss: 0.4819
# Epoch 2/75
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7796 - loss: 0.4780 - val_accuracy: 0.7801 - val_loss: 0.4762
# Epoch 3/75
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7790 - loss: 0.4778 - val_accuracy: 0.7796 - val_loss: 0.4725
# Epoch 4/75
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7808 - loss: 0.4776 - val_accuracy: 0.7801 - val_loss: 0.4722
# Epoch 5/75
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7766 - loss: 0.4790 - val_accuracy: 0.7815 - val_loss: 0.4756
# Epoch 6/75
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7768 - loss: 0.4838 - val_accuracy: 0.7794 - val_loss: 0.4816
# Epoch 7/75
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7788 - loss: 0.4752 - val_accuracy: 0.7789 - val_loss: 0.4750
# Epoch 8/75
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}, Accuracy: {accuracy}')
# Out:
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7926 - loss: 0.4600
# Loss: 0.47534802556037903, Accuracy: 0.7798416018486023

# %%
# [['AGR_SEXO','AGR_EST_CIV','AGR_TRABAJA', 'AGR_ESCOLARIDAD','AGR_EDAD','AGR_ALFAB']]
hecho = np.array([[1,4,2,49,30,1]])
res = model.predict(hecho)
print(res)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# [[0.35545963]]
